# %%
import pandas as pd
import os
import sys
dataset_folder = "/home/dipanshu/ownCloud/py080619/Datasets"

# %%
os.listdir(dataset_folder)
# Out:
# ['DailyProfileData.xlsx',
#  'Load Survey Data.xlsx',
#  'Street_light_Complaint_Details_last_6_Month.xlsx',
#  'Instant Raw Report.xlsx',
#  'maximumUsage.xlsx',
#  'DailyConsumption.xlsx']

# %%
FILES = os.listdir(dataset_folder)

# %%
FILES
# Out:
# ['DailyProfileData.xlsx',
#  'Load Survey Data.xlsx',
#  'Street_light_Complaint_Details_last_6_Month.xlsx',
#  'Instant Raw Report.xlsx',
#  'maximumUsage.xlsx',
#  'DailyConsumption.xlsx']

# %%
PDS = pd.read_excel(FILES)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-bd10b8ebbfcc> in <module>()
# ----> 1 PDS = pd.read_excel(FILES)
#
# /usr/local/lib/python3.5/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
# ...

# %%
PDS = [pd.read_excel(dataset_folder + "/" + i) for i in FILES]

# %%
PDS

# %%
PDS

# %%
type(PDS)

# %%
PDS[i]

# %%
pd

# %%
import pandas as pd

# %%
pd

# %%
pd

# %%
aa=1

# %%
aa

# %%
a=1

# %%
a
# Out:
# 1

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.5/dist-packages/pandas/__init__.py'>

# %%
PDS = [pd.read_excel(dataset_folder + "/" + i) for i in FILES]

# %%
PDS
# Out:
# [            CCMS ID            Timestamp   Cum kwh  Cum kVAh  \
#  0   SMR03-0219-0252  2019-05-01 00:00:00  7280.030  7323.073
#  1   SMR03-0219-0252  2019-04-30 00:00:00  7226.961  7269.618
#  2   SMR03-0219-0252  2019-04-29 00:00:00  7172.506  7214.758
#  3   SMR03-0219-0252  2019-04-28 00:00:00  7117.089  7158.920
#  4   SMR03-0219-0252  2019-04-27 00:00:00  7064.595  7106.040
#  5   SMR03-0219-0252  2019-04-26 00:00:00  7019.024  7060.118
#  6   SMR03-0219-0252  2019-04-25 00:00:00  6972.859  7013.632
#  7   SMR03-0219-0252  2019-04-24 00:00:00  6925.374  6965.812
#  8   SMR03-0219-0252  2019-04-23 00:00:00  6876.487  6916.608
#  9   SMR03-0219-0252  2019-04-22 00:00:00  6827.337  6867.129
#  10  SMR03-0219-0252  2019-04-21 00:00:00  6778.609  6818.047
#  11  SMR03-0219-0252  2019-04-20 00:00:00  6728.849  6767.929
#  12  SMR03-0219-0252  2019-04-19 00:00:00  6678.912  6717.638
#  13  SMR03-0219-0252  2019-04-18 00:00:00  6628.804  6667.148
# ...

# %%
PDS[0]
# Out:
#             CCMS ID            Timestamp   Cum kwh  Cum kVAh  \
# 0   SMR03-0219-0252  2019-05-01 00:00:00  7280.030  7323.073
# 1   SMR03-0219-0252  2019-04-30 00:00:00  7226.961  7269.618
# 2   SMR03-0219-0252  2019-04-29 00:00:00  7172.506  7214.758
# 3   SMR03-0219-0252  2019-04-28 00:00:00  7117.089  7158.920
# 4   SMR03-0219-0252  2019-04-27 00:00:00  7064.595  7106.040
# 5   SMR03-0219-0252  2019-04-26 00:00:00  7019.024  7060.118
# 6   SMR03-0219-0252  2019-04-25 00:00:00  6972.859  7013.632
# 7   SMR03-0219-0252  2019-04-24 00:00:00  6925.374  6965.812
# 8   SMR03-0219-0252  2019-04-23 00:00:00  6876.487  6916.608
# 9   SMR03-0219-0252  2019-04-22 00:00:00  6827.337  6867.129
# 10  SMR03-0219-0252  2019-04-21 00:00:00  6778.609  6818.047
# 11  SMR03-0219-0252  2019-04-20 00:00:00  6728.849  6767.929
# 12  SMR03-0219-0252  2019-04-19 00:00:00  6678.912  6717.638
# 13  SMR03-0219-0252  2019-04-18 00:00:00  6628.804  6667.148
# ...
