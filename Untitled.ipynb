# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
daily_consumption = pd.read_excel("Datasets/DailyConsumption (4).xlsx")

# %%
daily_consumption.head()
# Out:
#            CCMS ID            Timestamp  CCMS kWh  Grid kVAh  \
# 0  SMR03-0219-0792  2019-04-30 00:00:00     53.07      53.45
# 1  SMR03-0219-0792  2019-04-29 00:00:00     54.45      54.86
# 2  SMR03-0219-0792  2019-04-28 00:00:00     59.19      55.84
# 3  SMR03-0219-0792  2019-04-27 00:00:00     52.49      52.88
# 4  SMR03-0219-0792  2019-04-26 00:00:00     45.57      45.92
#
#   Meter ON Duration ON Load Duration  Expected kWh
# 0           23:15:1         10:13:17         52.84
# 1          23:19:30         10:25:20         53.88
# 2          23:58:29         10:48:38         55.89
# 3          23:58:40          11:21:3         58.68
# 4          23:57:51         10:51:38         56.15

# %%
daily_profile_data = pd.read_excel("Datasets/DailyProfileData (7).xlsx")
daily_profile_data.head()
# Out:
#            CCMS ID            Timestamp   Cum kwh  Cum kVAh Meter ON Duration  \
# 0  SMR03-0219-0252  2019-05-01 00:00:00  7280.030  7323.073        1592:54:22
# 1  SMR03-0219-0252  2019-04-30 00:00:00  7226.961  7269.618        1569:39:21
# 2  SMR03-0219-0252  2019-04-29 00:00:00  7172.506  7214.758        1546:19:51
# 3  SMR03-0219-0252  2019-04-28 00:00:00  7117.089  7158.920        1522:21:22
# 4  SMR03-0219-0252  2019-04-27 00:00:00  7064.595  7106.040        1498:22:42
#
#   Relay ON Duration
# 0         781:25:13
# 1         771:11:56
# 2         760:46:36
# 3         749:57:58
# 4         738:36:55

# %%
instant_raw_report = pd.read_excel("Datasets/Instant Raw Report (11).xlsx")
instant_raw_report.head()
# Out:
#            CCMS ID            Timestamp  Active Power kW  Apparent Power kVA  \
# 0  SMR03-0219-0252  2019-05-01 23:44:42             5.11                5.15
# 1  SMR03-0219-0252  2019-05-01 23:29:04             5.11                5.14
# 2  SMR03-0219-0252  2019-05-01 23:13:58             5.11                5.14
# 3  SMR03-0219-0252  2019-05-01 22:57:49             5.12                5.16
# 4  SMR03-0219-0252  2019-05-01 22:42:12             5.17                5.22
#
#    Current R (A)  Current Y (A)  Current B (A)  Voltage R (V)  Voltage Y (V)  \
# 0          10.66           5.47           5.85         233.48         234.57
# 1          10.65           5.48           5.83         233.56         234.34
# 2          10.74           5.52           5.89         231.74         232.72
# 3          10.73           5.53           5.90         232.01         233.22
# 4          10.79           5.55           5.92         233.17         234.27
#
#    Voltage B (V)             ...              B Phase kW  Active Mode  \
# 0         235.40             ...                    1.36         AUTO
# 1         235.45             ...                    1.35         AUTO
# 2         233.72             ...                    1.35         AUTO
# 3         234.14             ...                    1.36         AUTO
# 4         235.16             ...                    1.37         AUTO
#
#    Total Active Energy  Total Apparent Energy Current Day kWh  \
# 0             7329.234               7372.664          49.204
# 1             7327.901               7371.322          47.871
# 2             7326.616               7370.028          46.586
# 3             7325.238               7368.641          45.208
# 4             7323.899               7367.293          43.869
#
#   Current Day kVAh Power On Time(Hrs)  Relay on Time(Hrs)  \
# 0           49.591          1615:42:7            791:3:44
# 1           48.249         1615:26:31            790:48:8
# 2           46.955         1615:11:25            790:33:2
# 3           45.568         1614:55:17           790:16:54
# 4           44.220         1614:39:41            790:1:18
#
#    Current Day Meter on Period  Current Day Relay on Period
# 0                     22:47:44                      9:38:30
# 1                      22:32:8                      9:22:54
# 2                      22:17:2                       9:7:48
# 3                      22:0:54                      8:51:40
# 4                     21:45:18                       8:36:4
#
# [5 rows x 29 columns]

# %%
load_survey_data = pd.read_excel("Datasets/Load Survey Data (6).xlsx")
load_survey_data.head()
# Out:
#            CCMS ID            Timestamp    KWh   KVAh  Vr (Volt)  Vy (Volt)  \
# 0  SMR03-0219-0252  2019-05-01 23:00:00  2.732  2.752     233.23     234.30
# 1  SMR03-0219-0252  2019-05-01 22:00:00  5.108  5.143     236.64     238.00
# 2  SMR03-0219-0252  2019-05-01 21:00:00  5.120  5.156     237.01     238.69
# 3  SMR03-0219-0252  2019-05-01 20:00:00  4.985  5.025     237.29     238.79
# 4  SMR03-0219-0252  2019-05-01 19:00:00  0.372  0.375     244.08     245.06
#
#    Vb (Volt)  Ir (Amp)  Iy (Amp)  Ib (Amp)  Freq (Hz)   PF Total  Total Load
# 0     235.21     10.31      5.41      5.79      50.08  0.955  Ld        5.17
# 1     238.73     10.53      5.40      5.78      50.08  0.987  Ld        5.17
# 2     239.36     10.54      5.40      5.79      50.10  0.987  Ld        5.17
# 3     239.56      9.71      5.42      5.79      50.07  0.985  Ld        5.17
# 4     245.75      0.52      0.26      0.26      50.24  0.87  Lag        5.17

# %%
maximun_usage = pd.read_excel("Datasets/maximumUsage.xlsx")
maximun_usage
# Out:
#           CCMS ID.             Datetime  MD(kW)  I-R(A)  I-Y(A)  I-B(A)
# 0  SMR03-4218-0097  2019-04-30 23:23:21   21.37    0.02   18.01   31.54

# %%
complaint = pd.read_excel("Datasets/Street light Complaint Details last 6 Month.xlsx")

# %%
complaint.head()
# Out:
#                     Agent Call Status Date of Call Language Preference  \
# 0 2019-01-04  WEBCONSUMER        OPEN   2019-01-04             ENGLISH
# 1 2018-12-03  WEBCONSUMER        OPEN   2018-12-03             ENGLISH
# 2 2018-11-14  WEBCONSUMER        OPEN   2018-11-14             ENGLISH
# 3 2018-11-20  WEBCONSUMER        OPEN   2018-11-20             ENGLISH
# 4 2018-11-23  WEBCONSUMER        OPEN   2018-11-23             ENGLISH
#
#   Unique Query Number  8835216789  sumit anand  \
# 0        SLUP00104413  8835216789  sumit anand
# 1        SLUP00098562  8835216789  sumit anand
# 2        SLGJ00040122  8835216789  sumit anand
# 3        SLGJ00040291  8835216789  sumit anand
# 4        SLUP00096530  8835216789  sumit anand
#
#                                       Address                       Landmark  \
# 0                 C 12/15 LAHANGPURA VARANASU                       DR IQBAL
# 1  DIDAYAL NAGAR, DURGAKUND ,VARANASI -231005  DIDAYALNAGAR UDAYAN ( PARK .)
# 2    PLOT NO. 1270/A1,SECTOR-3/A, GANDHINAGAR                            NaN
# 3                 GOLD COIN HIGHMAST BLINKING    GOLD COIN HIGHMAST BLINKING
# 4                                 BADA LALPUR           TRADE CENTAR KE PASS
#
#           ...         Street Ligh Pole No Street Ligh Ticket Type  \
# 0         ...                           -     CABLES/POWER SUPPLY
# 1         ...                         NaN     CABLES/POWER SUPPLY
# 2         ...                         138                    LAMP
# 3         ...                         NaN                     NaN
# 4         ...                         NaN                  OTHERS
#
#   Street Ligh Assigned To Street Ligh Complaint From  \
# 0                     NaN                   RESIDENT
# 1                     NaN                   RESIDENT
# 2                     NaN                   RESIDENT
# 3                     NaN                   RESIDENT
# 4                     NaN                   RESIDENT
#
#   Answer given by call center Agent Date of Escalation  \
# 0                               NaN                NaN
# 1                               NaN                NaN
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                               NaN                NaN
#
#   Answer given by Level 2 Date of reply by Level 2 Escalate To  \
# 0                     NaN                      NaN         NaN
# 1                     NaN                      NaN         NaN
# 2                     NaN                      NaN         NaN
# 3                     NaN                      NaN         NaN
# 4                     NaN                      NaN         NaN
#
#   Date of Call Closer
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 28 columns]

# %%
import datetime
import time

def convert_to_unix(s):
    return time.mktime(datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S").timetuple())

def toUnix(df):
    df['UnixTimestamp'] = df.Timestamp.apply(convert_to_unix)
    return df

# %%
daily_consumption = toUnix(daily_consumption)

# %%
daily_consumption.columns
# Out:
# Index(['CCMS ID', 'Timestamp', 'CCMS kWh', 'Grid kVAh', 'Meter ON Duration',
#        'ON Load Duration', 'Expected kWh', 'UnixTimestamp'],
#       dtype='object')

# %%
daily_consumption.head()
# Out:
#            CCMS ID            Timestamp  CCMS kWh  Grid kVAh  \
# 0  SMR03-0219-0792  2019-04-30 00:00:00     53.07      53.45
# 1  SMR03-0219-0792  2019-04-29 00:00:00     54.45      54.86
# 2  SMR03-0219-0792  2019-04-28 00:00:00     59.19      55.84
# 3  SMR03-0219-0792  2019-04-27 00:00:00     52.49      52.88
# 4  SMR03-0219-0792  2019-04-26 00:00:00     45.57      45.92
#
#   Meter ON Duration ON Load Duration  Expected kWh  UnixTimestamp
# 0           23:15:1         10:13:17         52.84   1.556563e+09
# 1          23:19:30         10:25:20         53.88   1.556476e+09
# 2          23:58:29         10:48:38         55.89   1.556390e+09
# 3          23:58:40          11:21:3         58.68   1.556303e+09
# 4          23:57:51         10:51:38         56.15   1.556217e+09

# %%
daily_consumption.tail()
# Out:
#             CCMS ID            Timestamp  CCMS kWh  Grid kVAh  \
# 25  SMR03-0219-0792  2019-04-05 00:00:00     53.17      53.49
# 26  SMR03-0219-0792  2019-04-04 00:00:00     59.30      59.68
# 27  SMR03-0219-0792  2019-04-03 00:00:00     59.04      59.43
# 28  SMR03-0219-0792  2019-04-02 00:00:00     58.77      59.17
# 29  SMR03-0219-0792  2019-04-01 00:00:00     59.36      89.54
#
#    Meter ON Duration ON Load Duration  Expected kWh  UnixTimestamp
# 25          22:55:59         10:22:55         53.67   1.554403e+09
# 26          23:51:29         11:27:20         59.23   1.554316e+09
# 27          23:55:46          11:29:0         59.37   1.554230e+09
# 28          23:58:28         11:30:32         59.50   1.554143e+09
# 29          23:58:39         11:32:24         59.66   1.554057e+09

# %%
daily_profile_data = toUnix(daily_profile_data)

# %%
instant_raw_report = toUnix(instant_raw_report)

# %%
load_survey_data = toUnix(load_survey_data)

# %%
daily_consumption.columns
# Out:
# Index(['CCMS ID', 'Timestamp', 'CCMS kWh', 'Grid kVAh', 'Meter ON Duration',
#        'ON Load Duration', 'Expected kWh', 'UnixTimestamp'],
#       dtype='object')

# %%
daily_consumption = daily_consumption.set_index('Timestamp')

# %%
daily_consumption['CCMS kWh'].plot()

# %%
daily_consumption['Grid kVAh'].plot()

# %%
daily_consumption.head()
# Out:
#                              CCMS ID  CCMS kWh  Grid kVAh Meter ON Duration  \
# Timestamp
# 2019-04-30 00:00:00  SMR03-0219-0792     53.07      53.45           23:15:1
# 2019-04-29 00:00:00  SMR03-0219-0792     54.45      54.86          23:19:30
# 2019-04-28 00:00:00  SMR03-0219-0792     59.19      55.84          23:58:29
# 2019-04-27 00:00:00  SMR03-0219-0792     52.49      52.88          23:58:40
# 2019-04-26 00:00:00  SMR03-0219-0792     45.57      45.92          23:57:51
#
#                     ON Load Duration  Expected kWh  UnixTimestamp
# Timestamp
# 2019-04-30 00:00:00         10:13:17         52.84   1.556563e+09
# 2019-04-29 00:00:00         10:25:20         53.88   1.556476e+09
# 2019-04-28 00:00:00         10:48:38         55.89   1.556390e+09
# 2019-04-27 00:00:00          11:21:3         58.68   1.556303e+09
# 2019-04-26 00:00:00         10:51:38         56.15   1.556217e+09

# %%
complaint.head()
# Out:
#                     Agent Call Status Date of Call Language Preference  \
# 0 2019-01-04  WEBCONSUMER        OPEN   2019-01-04             ENGLISH
# 1 2018-12-03  WEBCONSUMER        OPEN   2018-12-03             ENGLISH
# 2 2018-11-14  WEBCONSUMER        OPEN   2018-11-14             ENGLISH
# 3 2018-11-20  WEBCONSUMER        OPEN   2018-11-20             ENGLISH
# 4 2018-11-23  WEBCONSUMER        OPEN   2018-11-23             ENGLISH
#
#   Unique Query Number  8835216789  sumit anand  \
# 0        SLUP00104413  8835216789  sumit anand
# 1        SLUP00098562  8835216789  sumit anand
# 2        SLGJ00040122  8835216789  sumit anand
# 3        SLGJ00040291  8835216789  sumit anand
# 4        SLUP00096530  8835216789  sumit anand
#
#                                       Address                       Landmark  \
# 0                 C 12/15 LAHANGPURA VARANASU                       DR IQBAL
# 1  DIDAYAL NAGAR, DURGAKUND ,VARANASI -231005  DIDAYALNAGAR UDAYAN ( PARK .)
# 2    PLOT NO. 1270/A1,SECTOR-3/A, GANDHINAGAR                            NaN
# 3                 GOLD COIN HIGHMAST BLINKING    GOLD COIN HIGHMAST BLINKING
# 4                                 BADA LALPUR           TRADE CENTAR KE PASS
#
#           ...         Street Ligh Pole No Street Ligh Ticket Type  \
# 0         ...                           -     CABLES/POWER SUPPLY
# 1         ...                         NaN     CABLES/POWER SUPPLY
# 2         ...                         138                    LAMP
# 3         ...                         NaN                     NaN
# 4         ...                         NaN                  OTHERS
#
#   Street Ligh Assigned To Street Ligh Complaint From  \
# 0                     NaN                   RESIDENT
# 1                     NaN                   RESIDENT
# 2                     NaN                   RESIDENT
# 3                     NaN                   RESIDENT
# 4                     NaN                   RESIDENT
#
#   Answer given by call center Agent Date of Escalation  \
# 0                               NaN                NaN
# 1                               NaN                NaN
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                               NaN                NaN
#
#   Answer given by Level 2 Date of reply by Level 2 Escalate To  \
# 0                     NaN                      NaN         NaN
# 1                     NaN                      NaN         NaN
# 2                     NaN                      NaN         NaN
# 3                     NaN                      NaN         NaN
# 4                     NaN                      NaN         NaN
#
#   Date of Call Closer
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 28 columns]

# %%
complaint.shape
# Out:
# (1048575, 28)

# %%
complaint.columns
# Out:
# Index([                              '   ',
#                                    'Agent',
#                              'Call Status',
#                             'Date of Call',
#                      'Language Preference',
#                      'Unique Query Number',
#                                 8835216789,
#                              'sumit anand',
#                                  'Address',
#                                 'Landmark',
#                                 'District',
#                                    'State',
#                                'Call Type',
#                                   'Scheme',
#                                   'Source',
#                         'Street Ligh Zone',
#                      'Street Ligh ULBName',
#                      'Street Ligh Ward No',
#                      'Street Ligh Pole No',
#                  'Street Ligh Ticket Type',
#                  'Street Ligh Assigned To',
#               'Street Ligh Complaint From',
#        'Answer given by call center Agent',
#                       'Date of Escalation',
#                  'Answer given by Level 2',
#                 'Date of reply by Level 2',
#                              'Escalate To',
#                      'Date of Call Closer'],
#       dtype='object')

# %%
complaint['Date of Call'].value_counts().plot()

# %%
complaint['Call Type'].value_counts()
# Out:
# COMPLAINT    157155
# QUERY             5
# OTHER             4
# Name: Call Type, dtype: int64

# %%
complaint['Street Ligh Ticket Type'].value_counts().plot(kind='bar')

# %%
complaint['Date of Call'].loc[complaint['Street Ligh Ticket Type'] == 'LAMP'].value_counts().plot()

# %%
complaint['Date of Call'].loc[complaint['Street Ligh Ticket Type'] == 'CCMS'].value_counts().plot()

# %%
instant_raw_report.columns
# Out:
# Index(['CCMS ID', 'Timestamp', 'Active Power kW', 'Apparent Power kVA',
#        'Current R (A)', 'Current Y (A)', 'Current B (A)', 'Voltage R (V)',
#        'Voltage Y (V)', 'Voltage B (V)', 'Total PF', 'Frequency (Hz)',
#        'MD kVA', 'MD kW', 'Load Relay Status R', 'Load Relay Status Y',
#        'Load Relay Status B', 'R Phase kW', 'Y Phase kW', 'B Phase kW',
#        'Active Mode', 'Total Active Energy', 'Total Apparent Energy',
#        'Current Day kWh', 'Current Day kVAh', 'Power On Time(Hrs)',
#        'Relay on Time(Hrs)', 'Current Day Meter on Period',
#        'Current Day Relay on Period', 'UnixTimestamp'],
#       dtype='object')

# %%
temp = instant_raw_report.set_index('Timestamp')

# %%
temp.head()
# Out:
#                              CCMS ID  Active Power kW  Apparent Power kVA  \
# Timestamp
# 2019-05-01 23:44:42  SMR03-0219-0252             5.11                5.15
# 2019-05-01 23:29:04  SMR03-0219-0252             5.11                5.14
# 2019-05-01 23:13:58  SMR03-0219-0252             5.11                5.14
# 2019-05-01 22:57:49  SMR03-0219-0252             5.12                5.16
# 2019-05-01 22:42:12  SMR03-0219-0252             5.17                5.22
#
#                      Current R (A)  Current Y (A)  Current B (A)  \
# Timestamp
# 2019-05-01 23:44:42          10.66           5.47           5.85
# 2019-05-01 23:29:04          10.65           5.48           5.83
# 2019-05-01 23:13:58          10.74           5.52           5.89
# 2019-05-01 22:57:49          10.73           5.53           5.90
# 2019-05-01 22:42:12          10.79           5.55           5.92
#
#                      Voltage R (V)  Voltage Y (V)  Voltage B (V)   Total PF  \
# Timestamp
# 2019-05-01 23:44:42         233.48         234.57         235.40  0.992  Ld
# 2019-05-01 23:29:04         233.56         234.34         235.45  0.992  Ld
# 2019-05-01 23:13:58         231.74         232.72         233.72  0.992  Ld
# 2019-05-01 22:57:49         232.01         233.22         234.14  0.992  Ld
# 2019-05-01 22:42:12         233.17         234.27         235.16  0.989  Ld
#
#                          ...       Active Mode  Total Active Energy  \
# Timestamp                ...
# 2019-05-01 23:44:42      ...              AUTO             7329.234
# 2019-05-01 23:29:04      ...              AUTO             7327.901
# 2019-05-01 23:13:58      ...              AUTO             7326.616
# 2019-05-01 22:57:49      ...              AUTO             7325.238
# 2019-05-01 22:42:12      ...              AUTO             7323.899
#
#                      Total Apparent Energy Current Day kWh Current Day kVAh  \
# Timestamp
# 2019-05-01 23:44:42               7372.664          49.204           49.591
# 2019-05-01 23:29:04               7371.322          47.871           48.249
# 2019-05-01 23:13:58               7370.028          46.586           46.955
# 2019-05-01 22:57:49               7368.641          45.208           45.568
# 2019-05-01 22:42:12               7367.293          43.869           44.220
#
#                     Power On Time(Hrs)  Relay on Time(Hrs)  \
# Timestamp
# 2019-05-01 23:44:42          1615:42:7            791:3:44
# 2019-05-01 23:29:04         1615:26:31            790:48:8
# 2019-05-01 23:13:58         1615:11:25            790:33:2
# 2019-05-01 22:57:49         1614:55:17           790:16:54
# 2019-05-01 22:42:12         1614:39:41            790:1:18
#
#                      Current Day Meter on Period  Current Day Relay on Period  \
# Timestamp
# 2019-05-01 23:44:42                     22:47:44                      9:38:30
# 2019-05-01 23:29:04                      22:32:8                      9:22:54
# 2019-05-01 23:13:58                      22:17:2                       9:7:48
# 2019-05-01 22:57:49                      22:0:54                      8:51:40
# 2019-05-01 22:42:12                     21:45:18                       8:36:4
#
#                     UnixTimestamp
# Timestamp
# 2019-05-01 23:44:42  1.556734e+09
# 2019-05-01 23:29:04  1.556734e+09
# 2019-05-01 23:13:58  1.556733e+09
# 2019-05-01 22:57:49  1.556732e+09
# 2019-05-01 22:42:12  1.556731e+09
#
# [5 rows x 29 columns]

# %%
temp[['Active Power kW','Apparent Power kVA']].plot(figsize = (16,12))

# %%
tmp = complaint

# %%
tmp['date_time'] = pd.to_datetime(complaint['Date of Call'], format="%y-%m-%d")

# %%
tmp.date_time.dt.month.value_counts()
# Out:
# 3.0     29133
# 4.0     28830
# 1.0     27375
# 2.0     26037
# 11.0    23242
# 12.0    22547
# Name: date_time, dtype: int64

# %%
tmp.head()
# Out:
#                     Agent Call Status Date of Call Language Preference  \
# 0 2019-01-04  WEBCONSUMER        OPEN   2019-01-04             ENGLISH
# 1 2018-12-03  WEBCONSUMER        OPEN   2018-12-03             ENGLISH
# 2 2018-11-14  WEBCONSUMER        OPEN   2018-11-14             ENGLISH
# 3 2018-11-20  WEBCONSUMER        OPEN   2018-11-20             ENGLISH
# 4 2018-11-23  WEBCONSUMER        OPEN   2018-11-23             ENGLISH
#
#   Unique Query Number  8835216789  sumit anand  \
# 0        SLUP00104413  8835216789  sumit anand
# 1        SLUP00098562  8835216789  sumit anand
# 2        SLGJ00040122  8835216789  sumit anand
# 3        SLGJ00040291  8835216789  sumit anand
# 4        SLUP00096530  8835216789  sumit anand
#
#                                       Address                       Landmark  \
# 0                 C 12/15 LAHANGPURA VARANASU                       DR IQBAL
# 1  DIDAYAL NAGAR, DURGAKUND ,VARANASI -231005  DIDAYALNAGAR UDAYAN ( PARK .)
# 2    PLOT NO. 1270/A1,SECTOR-3/A, GANDHINAGAR                            NaN
# 3                 GOLD COIN HIGHMAST BLINKING    GOLD COIN HIGHMAST BLINKING
# 4                                 BADA LALPUR           TRADE CENTAR KE PASS
#
#      ...     Street Ligh Ticket Type Street Ligh Assigned To  \
# 0    ...         CABLES/POWER SUPPLY                     NaN
# 1    ...         CABLES/POWER SUPPLY                     NaN
# 2    ...                        LAMP                     NaN
# 3    ...                         NaN                     NaN
# 4    ...                      OTHERS                     NaN
#
#   Street Ligh Complaint From Answer given by call center Agent  \
# 0                   RESIDENT                               NaN
# 1                   RESIDENT                               NaN
# 2                   RESIDENT                               NaN
# 3                   RESIDENT                               NaN
# 4                   RESIDENT                               NaN
#
#   Date of Escalation Answer given by Level 2 Date of reply by Level 2  \
# 0                NaN                     NaN                      NaN
# 1                NaN                     NaN                      NaN
# 2                NaN                     NaN                      NaN
# 3                NaN                     NaN                      NaN
# 4                NaN                     NaN                      NaN
#
#   Escalate To Date of Call Closer  date_time
# 0         NaN                 NaN 2019-01-04
# 1         NaN                 NaN 2018-12-03
# 2         NaN                 NaN 2018-11-14
# 3         NaN                 NaN 2018-11-20
# 4         NaN                 NaN 2018-11-23
#
# [5 rows x 29 columns]

# %%
tmp['Date of Call'][tmp.date_time.dt.month == 4.0].value_counts().plot()

# %%
a = tmp['Date of Call'][tmp.date_time.dt.month == 4.0].sort_index().value_counts()

# %%
temp1 = pd.read_excel('Datasets/DailyConsumption (4).xlsx')

# %%
temp1['date']=pd.to_datetime(temp1['Timestamp'])

# %%
temp1.set_index(['date'])
# Out:
#                     CCMS ID            Timestamp  CCMS kWh  Grid kVAh  \
# date
# 2019-04-30  SMR03-0219-0792  2019-04-30 00:00:00     53.07      53.45
# 2019-04-29  SMR03-0219-0792  2019-04-29 00:00:00     54.45      54.86
# 2019-04-28  SMR03-0219-0792  2019-04-28 00:00:00     59.19      55.84
# 2019-04-27  SMR03-0219-0792  2019-04-27 00:00:00     52.49      52.88
# 2019-04-26  SMR03-0219-0792  2019-04-26 00:00:00     45.57      45.92
# 2019-04-25  SMR03-0219-0792  2019-04-25 00:00:00     46.16      46.49
# 2019-04-24  SMR03-0219-0792  2019-04-24 00:00:00     47.49      47.82
# 2019-04-23  SMR03-0219-0792  2019-04-23 00:00:00     48.89      49.20
# 2019-04-22  SMR03-0219-0792  2019-04-22 00:00:00     49.15      49.48
# 2019-04-21  SMR03-0219-0792  2019-04-21 00:00:00     48.73      49.08
# 2019-04-20  SMR03-0219-0792  2019-04-20 00:00:00     49.76      50.12
# 2019-04-19  SMR03-0219-0792  2019-04-19 00:00:00     49.94      50.29
# 2019-04-18  SMR03-0219-0792  2019-04-18 00:00:00     50.11      50.49
# 2019-04-17  SMR03-0219-0792  2019-04-17 00:00:00     35.22      35.50
# 2019-04-16  SMR03-0219-0792  2019-04-16 00:00:00     40.58      40.88
# 2019-04-15  SMR03-0219-0792  2019-04-15 00:00:00     50.56      50.84
# 2019-04-14  SMR03-0219-0792  2019-04-14 00:00:00     43.70      43.94
# 2019-04-13  SMR03-0219-0792  2019-04-13 00:00:00     48.48      48.75
# 2019-04-12  SMR03-0219-0792  2019-04-12 00:00:00     49.12      49.39
# 2019-04-11  SMR03-0219-0792  2019-04-11 00:00:00     51.94      52.23
# 2019-04-10  SMR03-0219-0792  2019-04-10 00:00:00     54.82      55.14
# 2019-04-09  SMR03-0219-0792  2019-04-09 00:00:00     56.63      56.98
# 2019-04-08  SMR03-0219-0792  2019-04-08 00:00:00     52.07      52.32
# 2019-04-07  SMR03-0219-0792  2019-04-07 00:00:00     57.75      58.10
# 2019-04-06  SMR03-0219-0792  2019-04-06 00:00:00     55.27      55.61
# 2019-04-05  SMR03-0219-0792  2019-04-05 00:00:00     53.17      53.49
# 2019-04-04  SMR03-0219-0792  2019-04-04 00:00:00     59.30      59.68
# 2019-04-03  SMR03-0219-0792  2019-04-03 00:00:00     59.04      59.43
# 2019-04-02  SMR03-0219-0792  2019-04-02 00:00:00     58.77      59.17
# 2019-04-01  SMR03-0219-0792  2019-04-01 00:00:00     59.36      89.54
#
#            Meter ON Duration ON Load Duration  Expected kWh
# date
# 2019-04-30           23:15:1         10:13:17         52.84
# 2019-04-29          23:19:30         10:25:20         53.88
# 2019-04-28          23:58:29         10:48:38         55.89
# 2019-04-27          23:58:40          11:21:3         58.68
# 2019-04-26          23:57:51         10:51:38         56.15
# 2019-04-25           23:9:22         10:45:49         55.65
# 2019-04-24          23:52:29         10:54:43         56.41
# 2019-04-23          23:57:22         10:54:58         56.44
# 2019-04-22          23:52:17         10:57:49         56.68
# 2019-04-21          23:50:33          10:55:5         56.45
# 2019-04-20          23:58:28          11:0:58         56.95
# 2019-04-19          23:58:40          11:2:35         57.09
# 2019-04-18          23:25:26         10:57:49         56.68
# 2019-04-17           19:3:30           8:4:20         41.73
# 2019-04-16          21:27:11          9:10:12         47.41
# 2019-04-15           23:50:2          11:4:49         57.29
# 2019-04-14           22:9:11          9:23:11         48.53
# 2019-04-13          23:28:40         10:46:56         55.74
# 2019-04-12          23:21:44         11:13:55         58.07
# 2019-04-11          23:46:55         11:15:24         58.20
# 2019-04-10          23:56:49         11:16:28         58.29
# 2019-04-09          23:49:15         11:14:10         58.09
# 2019-04-08            23:4:6         11:18:33         58.47
# 2019-04-07          23:30:22          11:1:26         56.99
# 2019-04-06          23:20:13         10:49:12         55.94
# 2019-04-05          22:55:59         10:22:55         53.67
# 2019-04-04          23:51:29         11:27:20         59.23
# 2019-04-03          23:55:46          11:29:0         59.37
# 2019-04-02          23:58:28         11:30:32         59.50
# 2019-04-01          23:58:39         11:32:24         59.66

# %%
b = temp1['CCMS kWh']

# %%
b.plot()

# %%
a = daily_consumption.columns

# %%
b = daily_profile_data.columns

# %%
c = instant_raw_report.columns

# %%
d = load_survey_data.columns

# %%
a = list(a)

# %%
a.extend(list(b))

# %%
a.extend(list(c))

# %%
a.extend(list(d))

# %%
set(a)
# Out:
# {'Active Mode',
#  'Active Power kW',
#  'Apparent Power kVA',
#  'B Phase kW',
#  'CCMS ID',
#  'CCMS kWh',
#  'Cum kVAh',
#  'Cum kwh',
#  'Current B (A)',
#  'Current Day Meter on Period',
#  'Current Day Relay on Period',
#  'Current Day kVAh',
#  'Current Day kWh',
#  'Current R (A)',
#  'Current Y (A)',
#  'Expected kWh',
#  'Freq (Hz)',
#  'Frequency (Hz)',
#  'Grid kVAh',
#  'Ib (Amp)',
#  'Ir (Amp)',
#  'Iy (Amp)',
#  'KVAh',
#  'KWh',
#  'Load Relay Status B',
#  'Load Relay Status R',
#  'Load Relay Status Y',
#  'MD kVA',
#  'MD kW',
#  'Meter ON Duration',
#  'ON Load Duration',
#  'PF Total',
#  'Power On Time(Hrs)',
#  'R Phase kW',
#  'Relay ON Duration',
#  'Relay on Time(Hrs)',
#  'Timestamp',
#  'Total Active Energy',
#  'Total Apparent Energy',
#  'Total Load',
#  'Total PF',
#  'UnixTimestamp',
#  'Vb (Volt)',
#  'Voltage B (V)',
#  'Voltage R (V)',
#  'Voltage Y (V)',
#  'Vr (Volt)',
#  'Vy (Volt)',
#  'Y Phase kW'}

# %%
complaint.columns
# Out:
# Index([                              '   ',
#                                    'Agent',
#                              'Call Status',
#                             'Date of Call',
#                      'Language Preference',
#                      'Unique Query Number',
#                                 8835216789,
#                              'sumit anand',
#                                  'Address',
#                                 'Landmark',
#                                 'District',
#                                    'State',
#                                'Call Type',
#                                   'Scheme',
#                                   'Source',
#                         'Street Ligh Zone',
#                      'Street Ligh ULBName',
#                      'Street Ligh Ward No',
#                      'Street Ligh Pole No',
#                  'Street Ligh Ticket Type',
#                  'Street Ligh Assigned To',
#               'Street Ligh Complaint From',
#        'Answer given by call center Agent',
#                       'Date of Escalation',
#                  'Answer given by Level 2',
#                 'Date of reply by Level 2',
#                              'Escalate To',
#                      'Date of Call Closer',
#                                'date_time'],
#       dtype='object')

# %%
daily_consumption['CCMS ID'].value_counts()
# Out:
# SMR03-0219-0792    30
# Name: CCMS ID, dtype: int64

# %%
daily_profile_data['CCMS ID'].value_counts()
# Out:
# SMR03-0219-0252    31
# Name: CCMS ID, dtype: int64

# %%
instant_raw_report['CCMS ID'].value_counts()
# Out:
# SMR03-0219-0252    2677
# Name: CCMS ID, dtype: int64

# %%
load_survey_data['CCMS ID'].value_counts()
# Out:
# SMR03-0219-0252    742
# Name: CCMS ID, dtype: int64
